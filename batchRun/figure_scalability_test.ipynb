# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import matplotlib
# matplotlib.rcParams['pdf.fonttype'] = 42

# %%
plt.style.use("ggplot")

# %%
eps = [4, 16, 64, 256, 1024]
ns = [2 ** 22, 2 ** 24, 2 ** 26, 2 ** 28, 2 ** 30]
ns3 = [2 ** 22, 2 ** 24, 2 ** 26]
ns_time = {}
ns_time["k-ESF"] = [0.307742187,0.337835937,0.376773437,0.360429687,0.353429687]
ns_time["SpOT"] = [29.004734375,131.245359375,482.895859375,1955.675859375,9258.344859375]
ns_time["CLR"] = [16.1383125, 42.736132812,153.40125,607.335414062,2503.265875]
ns_time["KKRT"] = [4.723859375,19.098859375,83.799859375,608.658859375,2574.674859375]
ns_time["DH"] = [2752.872375,10862.9405,42400.785]
ns_time["PaXoS"] = [15.592578125, 58.1945, 250.89184375]
ns_time["CM"] = [23.559730468,110.980025,509.433064062,3074.643720312,22933.164345312]

ns_cost = {}
ns_cost["k-ESF"] = [146.81, 156.61, 173.97,167.05,167.05]
ns_cost["SpOT"] = [24.5,97.94,391.7,1566.74,6266.9]
ns_cost["CLR"] = [234.48,462.63,908.48,1800.19,3590.56]
ns_cost["KKRT"] = [307.22,1228.82,4915.22,19660.82,78643.22]
ns_cost["DH"] = [148,592,2368]
ns_cost["PaXoS"] = [568.38,2339.2,8997]
ns_cost["CM"] = [357.585,1442.272,5881.022,23716.022,96656.022]

nc = [1, 10, 100, 1000, 10000]
nc_time = {}
nc_time["k-ESF"] = [0.006765625,0.04065625,0.376773437,3.325398437,18.299875]
nc_time["SpOT"] = [6274.567929687,6484.474929687,6770.347859375,6920.533859375,7258.259625]
nc_time["CLR"] = [2503.265875,2503.265875,2503.265875,2503.265875,2503.265875]
nc_time["KKRT"] = [2043.161859375,2043.161859375,2043.161859375,2043.161859375,2043.161859375]
# nc_time["DH"] = [41586.376,41685.791,42400.785,41510.061,41728.017]
# nc_time["PaXoS"] = [250.89184375,250.89184375,250.89184375,250.89184375,250.89184375]
nc_time["CM"] = [22933.164345312,22933.164345312,22933.164345312,22933.164345312,22933.164345312]

nc_cost = {}
nc_cost["k-ESF"] = [1.74,17.4,173.97,1614.45,8472.485]
nc_cost["SpOT"] = [6266.9,6266.9,6266.9,6266.9,6266.9]
nc_cost["CLR"] = [3590.56,3590.56,3590.56,3590.56,3590.56]
nc_cost["KKRT"] = [78643.22,78643.22,78643.22,78643.22,78643.22]
nc_cost["DH"] = [2368,2368,2368,2368,2368]
nc_cost["PaXoS"] = [8997,8997,8997,8997,8997]
nc_cost["CM"] = [96656.022,96656.022,96656.022,96656.022,96656.022]

nsca1=[0.05]
nsca3=[0.05, 0.5, 1]
nsca4=[0.05, 0.5, 1, 2]
nsca5=[0.05, 0.5, 1, 2, 3]
nsca6=[0.05, 0.5, 1, 2, 3, 5]
nsca_time={}
nsca_time["k-ESF"] = [0.376773437,0.376773437,0.376773437,0.376773437,0.376773437,0.376773437]
nsca_time["SpOT"] = [482.895859375,3911.35171875,9258.344859375,21974.005929687,32961.008894531]
nsca_time["CLR"] = [153.40125,1222.265379687,2503.265875,5021.32597925,8052.322782187,11976.130757812]
nsca_time["KKRT"] = [83.799859375,1217.31771875,2574.674859375,5062.829859375]
nsca_time["DH"] = [42400.785]
nsca_time["PaXoS"] = [250.89184375]
nsca_time["CM"] = [509.433064062,11466.582172656,22933.164345312]

nsca_cost={}
nsca_cost["k-ESF"] = [173.97,173.97,173.97,173.97,173.97,173.97]
nsca_cost["SpOT"] = [391.7,3133.48,6266.9,12533.77,18800.655]
nsca_cost["CLR"] = [908.48,2520.266,3590.56,5070.4314,6218.0932,10692.87]
nsca_cost["KKRT"] = [4915.22,39321.64,78643.22,157286.42]
nsca_cost["DH"] = [2368]
nsca_cost["PaXoS"] = [8997]
nsca_cost["CM"] = [5881.022,48328.011,96656.022]


fs_construction_eps = {}
fs_construction_eps["flood"] = [1050, 1001, 991, 963, 968]
fs_construction_eps["lisa"]  = [1277, 1254, 1269, 1301, 1299]
fs_construction_eps["mli"]   = [12708, 12606, 12693, 12597, 12599]
fs_construction_eps["zm"]    = [174, 173, 172, 172, 173]

fs_range_eps = {}
fs_range_sel = [0.000794266, 0.00790489] # 2
fs_range_eps["flood"] = [187.9, 206.7, 195.7, 189.1, 179.5]
fs_range_eps["lisa"]  = [198.9, 190.3, 208.3, 203.8, 231.5]
fs_range_eps["mli"]   = [710, 1698.6, 712.3, 703.3, 734.8]
fs_range_eps["zm"]    = [361, 362.3, 351, 355, 347.3]

toronto_construction_eps = {}
toronto_construction_eps["flood"] = [11905, 10411, 9876, 9377, 9209]
toronto_construction_eps["lisa"]  = [7809, 7510, 7612, 7751, 7840]
toronto_construction_eps["mli"]   = [85345, 84942, 84623, 84965, 84937]
toronto_construction_eps["zm"]    = [1058, 1076, 1102, 1080, 1091]

toronto_range_eps = {}
toronto_range_sel = [0.0272086, 0.0701426] # 1
toronto_range_eps["flood"] = [9729.6, 11383.9, 10851.7, 11067.9, 12957]
toronto_range_eps["lisa"]  = [14126.6, 13823.9, 13270.7, 14323.5, 13238.7]
toronto_range_eps["mli"]   = [73384.3, 75303.9, 72632.2, 66859.7, 65648.5]
toronto_range_eps["zm"]    = [23827.7, 21774.5, 20699.1, 24248.1, 22203.4]

# %%
fig, ax = plt.subplots(figsize=(6, 5))
ax.plot(nsca6, nsca_time["k-ESF"], lw=2, color='r', marker='o', markersize=18, markerfacecolor='none', markeredgewidth=2, label='Flood', linestyle="-.")
ax.plot(nsca5, nsca_time["SpOT"], lw=2, color='g', marker='s', markersize=18, markerfacecolor='none', markeredgewidth=2, label='Lisa', linestyle="-.")
ax.plot(nsca6, nsca_time["CLR"], lw=2, color='b', marker='D', markersize=18, markerfacecolor='none', markeredgewidth=2, label='MLI', linestyle="-.")
ax.plot(nsca4, nsca_time["KKRT"], lw=2, color='k', marker='^', markersize=18, markerfacecolor='none', markeredgewidth=2, label='ZMI', linestyle="-.")
ax.plot(nsca1, nsca_time["DH"], lw=2, color='#800000', marker='x', markersize=18, markerfacecolor='none', markeredgewidth=2, label='ZMI', linestyle="-.")
ax.plot(nsca1, nsca_time["PaXoS"], lw=2, color='m', marker='*', markersize=18, markerfacecolor='none', markeredgewidth=2, label='ZMI', linestyle="-.")
ax.plot(nsca3, nsca_time["CM"], lw=2, color='#FFD700', marker='v', markersize=18, markerfacecolor='none', markeredgewidth=2, label='ZMI', linestyle="-.")

ax.set_yscale('log')
# ax.set_xscale('log', base=2)
ax.set_ylabel('Running Time (s)', fontsize=20)
ax.set_xlabel('$n_S$ (Billion)', fontsize=20)
plt.xticks(nsca6, ["0.05", "0.5","1","2", "3","5"], fontsize=20, rotation=-30)
# plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# plt.legend(ncol=2, fontsize=15)
plt.tight_layout()
plt.savefig("syn_scal_time.pdf")

# %%
fig, ax = plt.subplots(figsize=(6, 5))
ax.plot(nsca6, nsca_cost["k-ESF"], lw=2, color='r', marker='o', markersize=18, markerfacecolor='none', markeredgewidth=2, label='Flood', linestyle="-.")
ax.plot(nsca5, nsca_cost["SpOT"], lw=2, color='g', marker='s', markersize=18, markerfacecolor='none', markeredgewidth=2, label='Lisa', linestyle="-.")
ax.plot(nsca6, nsca_cost["CLR"], lw=2, color='b', marker='D', markersize=18, markerfacecolor='none', markeredgewidth=2, label='MLI', linestyle="-.")
ax.plot(nsca4, nsca_cost["KKRT"], lw=2, color='k', marker='^', markersize=18, markerfacecolor='none', markeredgewidth=2, label='ZMI', linestyle="-.")
ax.plot(nsca1, nsca_cost["DH"], lw=2, color='#800000', marker='x', markersize=18, markerfacecolor='none', markeredgewidth=2, label='ZMI', linestyle="-.")
ax.plot(nsca1, nsca_cost["PaXoS"], lw=2, color='m', marker='*', markersize=18, markerfacecolor='none', markeredgewidth=2, label='ZMI', linestyle="-.")
ax.plot(nsca3, nsca_cost["CM"], lw=2, color='#FFD700', marker='v', markersize=18, markerfacecolor='none', markeredgewidth=2, label='ZMI', linestyle="-.")

ax.set_yscale('log')
# ax.set_xscale('log', base=2)
ax.set_ylabel('Comm. Cost (MB)', fontsize=20)
ax.set_xlabel('$n_S$ (Billion)', fontsize=20)
plt.xticks(nsca6, ["0.05", "0.5","1","2", "3","5"], fontsize=20, rotation=-30)
# plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# plt.legend(ncol=2, fontsize=15, bbox_to_anchor=[1.0, 0.85])
plt.tight_layout()
plt.savefig("syn_scal_cost.pdf")

# %%
fig, ax = plt.subplots(figsize=(13, 5))
ax.plot(nc, nc_cost["k-ESF"], lw=2, color='r', marker='o', markersize=18, markerfacecolor='none', markeredgewidth=2, label='ESF', linestyle="-.")
ax.plot(nc, nc_cost["SpOT"], lw=2, color='g', marker='s', markersize=18, markerfacecolor='none', markeredgewidth=2, label='SpOT', linestyle="-.")
ax.plot(nc, nc_cost["CLR"], lw=2, color='b', marker='D', markersize=18, markerfacecolor='none', markeredgewidth=2, label='CLR', linestyle="-.")
ax.plot(nc, nc_cost["KKRT"], lw=2, color='k', marker='^', markersize=18, markerfacecolor='none', markeredgewidth=2, label='KKRT', linestyle="-.")
ax.plot(nc, nc_cost["DH"], lw=2, color='#800000', marker='x', markersize=18, markerfacecolor='none', markeredgewidth=2, label='ECDH', linestyle="-.")
ax.plot(nc, nc_cost["PaXoS"], lw=2, color='m', marker='*', markersize=18, markerfacecolor='none', markeredgewidth=2, label='PaXoS', linestyle="-.")
ax.plot(nc, nc_cost["CM"], lw=2, color='#FFD700', marker='v', markersize=18, markerfacecolor='none', markeredgewidth=2, label='CM', linestyle="-.")

ax.set_yscale('log')
ax.set_xscale('log', base=10)
ax.set_ylabel('Communication Cost (MB)', fontsize=17)
ax.set_xlabel('$n_S$', fontsize=17)
plt.xticks(nc, ["$10^{0}$", "$10^{1}$","$10^{2}$","$10^{3}$", "$10^{4}$"], fontsize=15)
plt.yticks(fontsize=15)
plt.legend(ncol=7, fontsize=15,loc=1, bbox_to_anchor=(1.0,1.3))
plt.tight_layout()
plt.savefig("legend_syn.svg")
